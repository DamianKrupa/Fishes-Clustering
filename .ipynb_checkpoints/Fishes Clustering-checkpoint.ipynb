# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
raw_data = pd.read_csv('Fish.csv')
data = raw_data.copy()

# %%
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
len(data['Species'].unique())
# Out:
# 7

# %%
data.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
if data.isnull().sum().sum() == 0:
    print('There are no missing values.')
# Out:
# There are no missing values.

# %%
data.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %% [markdown]
# ## Unscaled data

# %%
# create a variable which will contain the data for the clustering
x = data.iloc[:,1:].copy()
# create a k-means object with 2 clusters
kmeans = KMeans(7)
# fit the data
kmeans.fit(x)
# Out:
# KMeans(n_clusters=7)

# %%
# create a copy of data, so we can see the clusters next to the original data
clusters = data.iloc[:,1:].copy()
# predict the cluster for each observation
clusters['cluster_pred']=kmeans.fit_predict(x)

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
 
fig = plt.figure(figsize = (15, 10))
ax = plt.axes(projection ="3d")
 
ax.scatter3D(clusters['Width'], clusters['Weight'], clusters['Length3'], c= clusters['cluster_pred'], cmap = "rainbow")
plt.title("simple 3D scatter plot")
plt.show()

# %% [markdown]
# ## Standardize the variables

# %%
# import some preprocessing module
from sklearn import preprocessing
# scale the data for better results
x_scaled = preprocessing.scale(data.iloc[:,1:])
x_scaled
# Out:
# array([[-4.38072172e-01, -3.05788578e-01, -2.82303007e-01,
#         -1.06020232e-01,  5.96578670e-01, -2.36528948e-01],
#        [-3.03562184e-01, -2.25507242e-01, -1.98053663e-01,
#         -2.33668373e-03,  8.21260549e-01, -6.65789457e-02],
#        [-1.63447613e-01, -2.35542409e-01, -1.79331587e-01,
#         -1.09769794e-02,  7.97341291e-01,  1.65793169e-01],
#        [-9.89949100e-02,  5.30159764e-03,  5.46943678e-02,
#          1.96390116e-01,  8.79771455e-01,  2.26210031e-02],
#        [ 8.87586153e-02,  2.53719316e-02,  5.46943678e-02,
#          2.39591594e-01,  8.12834979e-01,  4.26371272e-01],
#        [ 1.44804444e-01,  5.54774324e-02,  1.20221635e-01,
#          3.00073664e-01,  1.08395111e+00,  3.03431249e-01],
#        [ 2.84919015e-01,  5.54774324e-02,  1.20221635e-01,
#          2.82793073e-01,  1.21901769e+00,  5.12357880e-01],
#        [-2.33330416e-02,  1.35758768e-01,  1.48304750e-01,
#          3.25994551e-01,  8.65728838e-01,  1.62163285e-01],
# ...

# %% [markdown]
# ## Scaled data

# %%
# create a k-means object with 2 clusters
kmeans_scaled = KMeans(7)
# fit the data
kmeans_scaled.fit(x_scaled)
# Out:
# KMeans(n_clusters=7)

# %%
# create a copy of data, so we can see the clusters next to the original data
clusters_scaled = data.copy()
# predict the cluster for each observation
clusters_scaled['cluster_pred']=kmeans_scaled.fit_predict(x_scaled)

# %%
fig = plt.figure(figsize = (15, 10))
ax = plt.axes(projection ="3d")
 
ax.scatter3D(clusters_scaled['Width'], clusters_scaled['Weight'], clusters_scaled['Length3'], c= clusters['cluster_pred'], cmap = "rainbow")
plt.title("simple 3D scatter plot")
plt.show()

# %%
fig = plt.figure(figsize = (15, 10))
ax = plt.axes(projection ="3d")
 
ax.scatter3D(clusters_scaled['Length3'], clusters_scaled['Weight'], clusters_scaled['Height'], c= clusters['cluster_pred'], cmap = "rainbow")
plt.title("simple 3D scatter plot")
plt.show()

# %% [markdown]
# ## Take Advantege of the Elbow Method

# %%
wcss = []
# 'cl_num' is a that keeps track the highest number of clusters we want to use the WCSS method for. We have it set at 10 right now, but it is completely arbitrary.
cl_num = 10
for i in range (1,cl_num):
    kmeans= KMeans(i)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
wcss
# Out:
# [954.0000000000003,
#  345.13618953575246,
#  249.78124923504978,
#  176.0813190578008,
#  131.5079940036888,
#  96.53874854031928,
#  75.01709766958747,
#  62.03436447878678,
#  54.28130230637198]

# %%
number_clusters = range(1,cl_num)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')
